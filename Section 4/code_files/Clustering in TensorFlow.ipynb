# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features= 2, centers= 4, cluster_std= 1.8, random_state=42)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0], data[0][:,1])

# %%
data[1]
# Out:
# array([1, 0, 3, 3, 2, 2, 1, 3, 1, 2, 2, 1, 1, 2, 2, 2, 0, 3, 2, 2, 2, 2, 3,
#        0, 3, 0, 0, 2, 0, 1, 2, 2, 3, 3, 0, 1, 3, 1, 3, 0, 2, 0, 2, 2, 3, 1,
#        1, 2, 1, 0, 3, 0, 3, 1, 0, 0, 2, 2, 0, 1, 3, 1, 2, 3, 3, 2, 1, 0, 3,
#        0, 0, 3, 0, 2, 1, 2, 1, 0, 2, 0, 0, 1, 2, 3, 3, 3, 3, 0, 1, 3, 2, 0,
#        1, 1, 1, 3, 0, 1, 2, 0, 3, 3, 0, 2, 0, 1, 3, 2, 2, 3, 1, 2, 0, 3, 0,
#        3, 3, 0, 0, 0, 3, 2, 1, 3, 3, 1, 0, 1, 1, 0, 2, 2, 0, 3, 3, 1, 2, 2,
#        0, 2, 1, 0, 3, 1, 1, 0, 1, 3, 2, 2, 0, 3, 1, 3, 2, 3, 3, 1, 1, 1, 0,
#        1, 1, 3, 0, 2, 1, 1, 2, 1, 3, 0, 2, 2, 1, 2, 1, 0, 0, 2, 0, 2, 3, 3,
#        3, 0, 1, 1, 1, 0, 0, 2, 3, 3, 0, 3, 1, 0, 2, 1])

# %%
plt.scatter(data[0][:,0], data[0][:,1],c= data[1], cmap='rainbow')

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-10.73535355,   7.58003616],
#        [ -4.40169591,  -7.62892962],
#        [ -3.41278305,   7.60290621],
#        [  5.26046598,   3.80142761],
#        [ -7.71315904,  -6.55244496],
#        [ -7.94876301,   7.60986411],
#        [ -1.98011365,  10.31573598],
#        [  3.97291084,   1.08302862]])

# %%
kmeans.labels_
# Out:
# array([3, 5, 5, 0, 4, 1, 7, 0, 3, 1, 4, 3, 3, 4, 4, 4, 6, 0, 1, 1, 1, 4, 5,
#        2, 5, 6, 2, 4, 2, 7, 4, 1, 0, 0, 6, 7, 5, 3, 5, 2, 4, 2, 4, 1, 0, 7,
#        7, 4, 7, 6, 2, 2, 5, 7, 2, 6, 1, 4, 2, 7, 5, 3, 1, 5, 5, 4, 7, 2, 5,
#        6, 2, 5, 2, 4, 7, 4, 7, 6, 4, 2, 2, 7, 4, 5, 5, 5, 5, 2, 7, 5, 4, 2,
#        7, 7, 3, 0, 2, 3, 4, 2, 5, 0, 2, 4, 6, 3, 5, 4, 1, 0, 3, 4, 2, 5, 6,
#        0, 5, 2, 6, 2, 2, 1, 7, 5, 5, 3, 6, 7, 7, 6, 1, 4, 6, 5, 0, 3, 4, 1,
#        6, 1, 7, 2, 0, 7, 3, 2, 7, 5, 4, 4, 2, 5, 3, 5, 4, 5, 0, 7, 7, 7, 6,
#        7, 3, 5, 6, 4, 7, 7, 4, 3, 5, 2, 4, 1, 3, 1, 3, 2, 6, 4, 2, 4, 5, 5,
#        5, 6, 3, 3, 7, 6, 2, 4, 0, 0, 2, 5, 3, 6, 4, 3], dtype=int32)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, sharey=True,figsize=(10,6))

ax1.set_title('K-Means')
ax1.scatter(data[0][:,0], data[0][:,1],c= kmeans.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1],c= data[1], cmap='rainbow')

# %% [markdown]
# # Greate Job !!!
